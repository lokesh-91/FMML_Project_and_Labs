# %% [markdown]
# <a href="https://colab.research.google.com/github/lokesh-91/FMML_Project_and_Labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-25 06:42:43--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   214MB/s    in 0.3s
#
# 2024-03-25 06:42:44 (214 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 19906   1303.5394v1  Influence diagram is a graphical representatio...    cs
# 32152  1604.03986v1  Policy advice is a transfer learning method wh...    cs
# 6021   1606.01160v1  Although many successful ensemble clustering a...  stat
# 2863   1803.01489v1  We introduce Recurrent Predictive State Policy...  stat
# 15283   1112.6286v1  A step-to-step introduction is provided on how...    cs
# ...             ...                                                ...   ...
# 11067   1312.7022v1  Model-based clustering approaches concern the ...  stat
# 13075  1506.02222v5  Ordinary least squares (OLS) is the default me...  stat
# 3765    1412.5896v3  In this work we study the properties of deep n...  stat
# 39371  1601.02970v1  The complex multi-stage architecture of cortic...    cs
# 12631  1803.07859v1  Bayesian networks are probabilistic graphical ...  stat
#
#                                                    title  year  \
# 19906  Structural Controllability and Observability i...  2013
# 32152  Theoretically-Grounded Policy Advice from Mult...  2016
# 6021   Robust Ensemble Clustering Using Probability T...  2016
# 2863          Recurrent Predictive State Policy Networks  2018
# 15283  Visualization and Analysis of Frames in Collec...  2011
# ...                                                  ...   ...
# 11067  Robust EM algorithm for model-based curve clus...  2013
# 13075  No penalty no tears: Least squares in high-dim...  2015
# 3765                   On the Stability of Deep Networks  2014
# 39371  Deep Neural Networks predict Hierarchical Spat...  2016
# 12631  Efficient Structure Learning and Sampling of B...  2018
#
#                                                 keywords
# 19906  [influence, graphical, representation, uncerta...
# 32152  [reinforcement, theoretical, introduces, algor...
# 6021   [successful, clustering, approaches, developed...
# 2863   [introduce, recurrent, predictive, recurrent, ...
# 15283  [introduction, collection, paragraphs, availab...
# ...                                                  ...
# 11067  [clustering, approaches, exploratory, automati...
# 13075  [applicable, dimensionality, generalized, moti...
# 3765   [properties, preserving, embedding, conclusion...
# 39371  [architecture, efficient, recognition, computa...
# 12631  [probabilistic, graphical, understand, depende...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 19906    [influence, graphical, representation, uncerta...
# 32152    [reinforcement, theoretical, introduces, algor...
# 6021     [successful, clustering, approaches, developed...
# 2863     [introduce, recurrent, predictive, recurrent, ...
# 15283    [introduction, collection, paragraphs, availab...
#                                ...
# 35891    [propositional, assignment, satisfies, backbon...
# 12556    [reinforcement, algorithms, reinforcement, suc...
# 6099     [approximate, inference, information, projecti...
# 764      [information, retrieval, knowledge, improving,...
# 868      [probabilistic, framework, rendering, generati...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8885 words.
# Out of those 4593 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="493fb76d-2db1-4640-b064-0033246e01c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("493fb76d-2db1-4640-b064-0033246e01c5")) {                    Plotly.newPlot(                        "493fb76d-2db1-4640-b064-0033246e01c5",                        [{"x":["sometimes","particular","inconsistency","developed","qualitative","structural","algorithms","variables","reasoning","uncertainty","influence","graphical","formulating","fundamental","dependence","numerical","challenging","formulated","functional","comprehending","underlying","knowledge","intuitions","insufficient","controllability","structure","determined","connection","corresponds","probabilistic","detecting","representation","information","properties","observability","theoretical","applications","intuition","formalization","exploration","theoretically","autonomous","reinforcement","introduces","algorithm","trajectories","similarity","reliability","clustering","approaches","efficiency","transition","functions","consensus","probability","regardless","significantly","analyzing","generally","uncertain","limitations","effectiveness","demonstrate","experimental","thresholds","successful","selection","incorporate","trajectory","interpretation","predictive","empirically","representations","observations","simplifying","initialize","conditioned","consistent","differentiable","introduce","prediction","environment","behaviour","architecture","environments","performing","therefore","cumulative","leverages","preserving","combination","partially","recurrent","equivalent","observable","recursive","statistically","component","incorporating","distribution","relations","paragraphs","recursively","measurement","statistics","generated","positioned","linguistics","introduction","distinguish","discussed","techniques","visualization","collections","positions","collection","communicated","communicate","available","considered","communication","adaptation","formulation","framework","conditional","transformation","discrepancy","different","densities","distributions","regression","benchmark","effective","exponential","unsupervised","estimation","transforming","potential","dependency","optimizing","automatic","interconnected","technique","designing","superiority","controller","parameters","performance","controllers","bacterial","conventional","regulation","mathematical","parameter","separately","matlabsimulink","equations","optimization","deviation","computation","increased","frequency","responses","intelligent","undershoot","connected","comprises","optimized","obtaining","marginally","computationally","generation","comparison","variation","processor","alternating","comparable","centralized","direction","scenarios","convergence","synthetic","distributed","reconstruction","estimates","formulations","furthermore","alternate","scalability","orientation","processing","acquisition","multipliers","implementation","adjustment","incrementally","illustrate","quantitative","coefficients","condition"],"y":[23,273,8,194,59,88,586,131,130,85,61,62,11,88,31,84,276,48,46,2,139,388,7,15,2,385,39,41,24,147,76,352,711,239,4,146,457,18,10,45,31,71,110,75,801,35,145,30,138,453,166,35,221,16,157,13,259,55,64,25,62,201,565,365,6,77,171,70,24,79,62,74,227,79,5,8,18,86,30,292,239,120,32,249,78,67,146,11,32,39,155,38,158,63,18,26,23,108,50,204,114,3,14,36,59,186,2,13,31,23,70,373,30,17,31,76,2,11,310,123,57,64,89,531,95,64,17,734,9,112,117,200,221,34,149,174,14,147,41,46,171,8,226,32,41,11,255,880,13,1,107,5,80,120,30,2,33,330,16,151,45,57,29,46,2,71,11,56,45,2,97,147,131,52,10,33,100,11,63,77,112,119,92,110,62,15,145,9,41,34,302,47,19,127,12,17,85,70,45,61],"type":"bar"},{"x":["sometimes","particular","inconsistency", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4593,), (4593, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8075

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Logical</span> <span style=''>methods</span> <span style=''>of</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.6093418259023355);'>recognition</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3636363636363637);'>satellite</span> <span style=''>images</span> <span style=''>using</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <br/><br/><span style=''>A</span> <span style=''>logical</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.6093418259023355);'>recognition</span> <span style=''>on</span> <span style=''>image</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>The</span> <span style=''>main</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>the</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>the</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.6093418259023355);'>recognition</span> <span style=''>as</span> <span style=''>a</span> <span style=''>logical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>on</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>rules</span> <span style='background-color:rgba(0, 255, 0, 0.47619047619047616);'>describing</span> <span style=''>an</span> <span style=''>object</span> <span style=''>shape</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Directional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistics</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Permutations</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Distributions</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutations</span> <span style=''>arise</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>ranging</span> <span style=''>from</span> <span style=''>multi</span> <span style=''>object</span> <span style=''>tracking</span> <span style=''>to</span> <span style=''>ranking</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instances</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficulty</span> <span style=''>of</span> <span style=''>dealing</span> <span style=''>with</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>is</span> <span style=''>caused</span> <span style=''>by</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>their</span> <span style=''>domain</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorial</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>entities</span> <span style=''>(n)</span> <span style=''>It</span> <span style=''>makes</span> <span style=''>the</span> <span style=''>direct</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>definition</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multinomial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutation</span> <span style=''>space</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>impractical</span> <span style=''>for</span> <span style=''>all</span> <span style=''>but</span> <span style=''>a</span> <span style=''>very</span> <span style=''>small</span> <span style=''>n</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>of</span> <span style=''>all</span> <span style=''>n</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutations</span> <span style=''>for</span> <span style=''>a</span> <span style=''>given</span> <span style=''>n</span> <span style=''>in</span> <span style=''>a</span> <span style=''>surface</span> <span style=''>of</span> <span style=''>a</span> <span style=''>hypersphere</span> <span style=''>defined</span> <span style=''>in</span> <span style=''>mathbbmR(n</span> <span style=''>1)2</span> <span style=''>As</span> <span style=''>a</span> <span style=''>result</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>we</span> <span style=''>acquire</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>define</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>over</span> <span style=''>a</span> <span style=''>hypersphere</span> <span style=''>with</span> <span style=''>all</span> <span style=''>the</span> <span style=''>benefits</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>directional</span> <span style='backgro ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Scalable</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processes</span> <span style=''>with</span> <span style=''>Billions</span> <span style=''>of</span> <span style=''>Inducing</span> <span style=''>Inputs</span> <span style=''>via</span> <span style=''>Tensor</span> <span style=''>Train</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Decomposition</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>(TT</span> <span style=''>GP)</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>(GP)</span> <span style=''>models</span> <span style=''>We</span> <span style=''>build</span> <span style=''>on</span> <span style=''>previous</span> <span style=''>scalable</span> <span style=''>GP</span> <span style=''>research</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style='background-color:rgba(255, 0, 0, 0.3656174334140436);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.5371900826446281);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>based</span> <span style=''>on</span> <span style=''>inducing</span> <span style=''>inputs</span> <span style=''>kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploiting</span> <span style=''>algebra</span> <span style=''>The</span> <span style=''>key</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>our</span> <span style=''>method</span> <span style=''>is</span> <span style=''>to</span> <span style=''>use</span> <span style=''>Tensor</span> <span style=''>Train</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.5371900826446281);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>which</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>train</span> <span style=''>GPs</span> <span style=''>with</span> <span style=''>billions</span> <span style=''>of</span> <span style=''>inducing</span> <span style=''>inputs</span> <span style=''>and</span> <span style=''>achieve</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>results</span> <span style=''>on</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.489051094890511);'>benchmarks</span> <span style=''>Further</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>allows</span> <span style=''>for</span> <span style=''>training</span> <span style=''>kernels</span> <span style=''>based</span> <span style=''>on</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>without</span> <span style=''>any</span> <span style='background-color:rgba(0, 255, 0, 0.3714285714285714);'>modifications</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>GP</span> <span style=''>model</span> <span style=''>A</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>learns</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multidimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>for</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Discriminative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Similarity</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>and</span> <span style=''>Semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Supervised</span> <span style=''>Learning</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Similarity</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>and</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>separate</span> <span style=''>the</span> <span style=''>data</span> <span style=''>into</span> <span style=''>clusters</span> <span style=''>or</span> <span style=''>classes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>according</span> <span style=''>to</span> <span style=''>the</span> <span style=''>pairwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>between</span> <span style=''>the</span> <span style=''>data</span> <span style=''>and</span> <span style=''>the</span> <span style=''>pairwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>is</span> <span style=''>crucial</span> <span style=''>for</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>which</span> <span style=''>learns</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>for</span> <span style=''>either</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>or</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>learns</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>from</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothetical</span> <span style=''>labeling</span> <span style=''>and</span> <span style=''>searches</span> <span style=''>for</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>labeling</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>error</span> <span style=''>of</span> <span style=''>the</span> <span style=''>learned</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothetical</span> <span style=''>labeling</span> <span style=''>Kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>is</span> <span style=''>employed</span> <span style=''>in</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>By ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08940754039497308)
# 	processing (0.10843806104129264)
# 	experimental (0.1310592459605027)
# 	segmentation (0.07791741472172352)
# 	information (0.2552962298025135)
# 	detection (0.11561938958707361)
# 	knowledge (0.1393177737881508)
# 	different (0.26355475763016156)
# 	recognition (0.13608617594254938)
# 	convolutional (0.1400359066427289)
#
# Some Statistics words are:
# 	variables (0.13399503722084366)
# 	stochastic (0.13995037220843673)
# 	theoretical (0.14739454094292803)
# 	algorithm (0.3890818858560794)
# 	statistical (0.15732009925558313)
# 	distribution (0.18312655086848637)
# 	estimation (0.17320099255583127)
# 	inference (0.19851116625310175)
# 	regression (0.16327543424317617)
# 	dimensional (0.18957816377171216)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f5416e4f-67ad-4492-9753-a9be0f7dcc19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5416e4f-67ad-4492-9753-a9be0f7dcc19")) {                    Plotly.newPlot(                        "f5416e4f-67ad-4492-9753-a9be0f7dcc19",                        [{"x":["sometimes","particular","inconsistency","developed","qualitative","structural","algorithms","variables","reasoning","uncertainty","influence","graphical","formulating","fundamental","dependence","numerical","challenging","formulated","functional","comprehending","underlying","knowledge","intuitions","insufficient","controllability","structure","determined","connection","corresponds","probabilistic","detecting","representation","information","properties","observability","theoretical","applications","intuition","formalization","exploration","theoretically","autonomous","reinforcement","introduces","algorithm","trajectories","similarity","reliability","clustering","approaches","efficiency","transition","functions","consensus","probability","regardless","significantly","analyzing","generally","uncertain","limitations","effectiveness","demonstrate","experimental","thresholds","successful","selection","incorporate","trajectory","interpretation","predictive","empirically","representations","observations","simplifying","initialize","conditioned","consistent","differentiable","introduce","prediction","environment","behaviour","architecture","environments","performing","therefore","cumulative","leverages","preserving","combination","partially","recurrent","equivalent","observable","recursive","statistically","component","incorporating","distribution","relations","paragraphs","recursively","measurement","statistics","generated","positioned","linguistics","introduction","distinguish","discussed","techniques","visualization","collections","positions","collection","communicated","communicate","available","considered","communication","adaptation","formulation","framework","conditional","transformation","discrepancy","different","densities","distributions","regression","benchmark","effective","exponential","unsupervised","estimation","transforming","potential","dependency","optimizing","automatic","interconnected","technique","designing","superiority","controller","parameters","performance","controllers","bacterial","conventional","regulation","mathematical","parameter","separately","matlabsimulink","equations","optimization","deviation","computation","increased","frequency","responses","intelligent","undershoot","connected","comprises","optimized","obtaining","marginally","computationally","generation","comparison","variation","processor","alternating","comparable","centralized","direction","scenarios","convergence","synthetic","distributed","reconstruction","estimates","formulations","furthermore","alternate","scalability","orientation","processing","acquisition","multipliers","implementation","adjustment","incrementally","illustrate","quantitative","coefficients","condition","identified","sufficient","conclusions","parametrization","interventions","predicting","statistical","representing","represents","compatible","identification","experiments","segmentation","realistic","convolutional","laborious","necessary","outperforms","superpixels","curriculum","decreases","baselines","buildings","predictions","industrial","difficult","annotations","synchronous","stochastic","understand","efficient","gradients","coordinate","increasing","rescaling","deteriorate","sequential","parallelizable","experimentally","similarly","procedure","significant","aggregation","compositions","conducted","diversity","decreasing","empirical","dimension","contraction","complementary","objectives","populations", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	bernsteins
# 	diffraction
# 	delineates
# 	proteomics
# 	inversions
# 	preselected
# 	looseness
# 	intriguingly
# 	indications
# 	eigenvector
# 	autocorrelation
# 	misclassifications
# 	entrywise
# 	thetastar
# 	repeating
# 	barycenters
# 	barycenter
# 	robustification
# 	amortization
# 	intracellular
# Some words which never appear in Statistics papers:
# 	comprehending
# 	controllability
# 	paragraphs
# 	matlabsimulink
# 	undershoot
# 	buildings
# 	thesaurus
# 	lemmatization
# 	neurophysiological
# 	logically
# 	installed
# 	recognizes
# 	declarative
# 	dialogues
# 	adaptable
# 	organizations
# 	committees
# 	reachability
# 	satisfiability
# 	mammography

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.082329007798292e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7541666666666667
